# %%
import pandas as pd
import re
import string

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data=pd.read_csv('/content/drive/MyDrive/gujarati_transalated.csv')
data
# Out:
#       Unnamed: 0                                              tweet
# 0              0  @Jake_M_Johnson તમે લોકોએ તમારા શસ્ત્રોનો ઉપયો...
# 1              1  @ItsFuckingKojot તેણે તેમને ગોળી મારી. બંદૂક સ...
# 2              2  એલેક બાલ્ડવિને ક્રુક્ડ કિલરીના દુશ્મનને ગોળી મ...
# 3              3  @VanJones68 બાર્કલે સેન્ટરમાં ખરેખર શું બન્યું...
# 4              4  "સમગ્ર કાઉન્ટીમાં સામૂહિક, વ્યાપક વોકઆઉટ ફળમાં...
# ...          ...                                                ...
# 5990        5990  @JacquesMaree73 @CSYoung42 @stabestweet @Wilki...
# 5991        5991  @જોશુઆપોટાશ તેઓ વધુ સારી સારવાર માટેના કરાર મા...
# 5992        5992  @TommyFree98 @BS1339 @KellyScaletta @ajplus હી...
# 5993        5993  યિનમારબિન ટાઉનશીપના યેકીપિન ગામમાં, આજે સાંજે ...
# 5994        5994  "સેમિટિક વિરોધી દ્વેષપૂર્ણ ગુનાઓ વધી રહ્યા છે ...
#
# [5995 rows x 2 columns]

# %%
df_clean = data

# %%
#newline replaced by spaces

df_clean.tweet = df_clean.tweet.apply(lambda x: re.sub(r"\n", ' ', x))

# %%
#english nos and text(all links, hashtags, mentions)
df_clean.tweet = df_clean.tweet.apply(lambda x: re.sub(r"[a-zA-Z0-9]", ' ', x))
#marathi nos and fullstops etc
df_clean.tweet = df_clean.tweet.apply(lambda x: re.sub(r"[१२३४५६७८९०₹•…॥।]", " ", x))

# %%
def remove_emojis(data):
    emoj = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U00002702-\U000027B0"
        u"\U00002702-\U000027B0"
        u"\U000024C2-\U0001F251"
        u"\U0001f926-\U0001f937"
        u"\U00010000-\U0010ffff"
        u"\u2640-\u2642" 
        u"\u2600-\u2B55"
        u"\u200d"
        u"\u23cf"
        u"\u23e9"
        u"\u231a"
        u"\ufe0f"  # dingbats
        u"\u3030"              "]+", re.UNICODE)
    return re.sub(emoj, '', data)

df_clean.tweet = df_clean.tweet.apply(remove_emojis)

# %%
def remove_punctuations(tweet):
    for punctuation in string.punctuation:
        tweet = tweet.replace(punctuation, ' ')
    return tweet

df_clean.tweet = df_clean.tweet.apply(remove_punctuations)

# %%
#multiple spaces -> single space
df_clean.tweet = df_clean.tweet.apply(lambda x: re.sub(r"  +", " ", x))

# %%
df_clean
# Out:
#       Unnamed: 0                                              tweet
# 0              0   તમે લોકોએ તમારા શસ્ત્રોનો ઉપયોગ કરીને દાયકાઓથ...
# 1              1   તેણે તેમને ગોળી મારી બંદૂક સાથે બંદૂક સાથે વિ...
# 2              2  એલેક બાલ્ડવિને ક્રુક્ડ કિલરીના દુશ્મનને ગોળી મ...
# 3              3   બાર્કલે સેન્ટરમાં ખરેખર શું બન્યું તે વિશે ફર...
# 4              4   સમગ્ર કાઉન્ટીમાં સામૂહિક વ્યાપક વોકઆઉટ ફળમાં ...
# ...          ...                                                ...
# 5990        5990   રસીકરણના અત્યાચારી અમલ નો વિરોધ કરવા અસિનિન પ...
# 5991        5991   જોશુઆપોટાશ તેઓ વધુ સારી સારવાર માટેના કરાર મા...
# 5992        5992   હીરો માઈલ દૂર એક વિરોધ પ્રદર્શનમાં લશ્કરી જવા...
# 5993        5993  યિનમારબિન ટાઉનશીપના યેકીપિન ગામમાં આજે સાંજે લ...
# 5994        5994   સેમિટિક વિરોધી દ્વેષપૂર્ણ ગુનાઓ વધી રહ્યા છે ...
#
# [5995 rows x 2 columns]

# %%
df_clean.to_csv("guju_from_english.csv")

# %%
df=df_clean.copy()

# %%
df
# Out:
#       Unnamed: 0                                              tweet
# 0              0   તમે લોકોએ તમારા શસ્ત્રોનો ઉપયોગ કરીને દાયકાઓથ...
# 1              1   તેણે તેમને ગોળી મારી બંદૂક સાથે બંદૂક સાથે વિ...
# 2              2  એલેક બાલ્ડવિને ક્રુક્ડ કિલરીના દુશ્મનને ગોળી મ...
# 3              3   બાર્કલે સેન્ટરમાં ખરેખર શું બન્યું તે વિશે ફર...
# 4              4   સમગ્ર કાઉન્ટીમાં સામૂહિક વ્યાપક વોકઆઉટ ફળમાં ...
# ...          ...                                                ...
# 5990        5990   રસીકરણના અત્યાચારી અમલ નો વિરોધ કરવા અસિનિન પ...
# 5991        5991   જોશુઆપોટાશ તેઓ વધુ સારી સારવાર માટેના કરાર મા...
# 5992        5992   હીરો માઈલ દૂર એક વિરોધ પ્રદર્શનમાં લશ્કરી જવા...
# 5993        5993  યિનમારબિન ટાઉનશીપના યેકીપિન ગામમાં આજે સાંજે લ...
# 5994        5994   સેમિટિક વિરોધી દ્વેષપૂર્ણ ગુનાઓ વધી રહ્યા છે ...
#
# [5995 rows x 2 columns]

# %%
output=df.tweet.drop_duplicates()

# %%
# Out:
# 0        અમિતભાઈ કાશ્મીર ગયા જ છો તો દિવસ વધારે રોકાઈન...
# 1                            ગુજરાતહોમગાર્ડ નો પગાર વધારો
# 62       પોલીસ વાળા હપ્તા ઉઘરાવી ધંધો કરાવે છે એનું શુ...
# 83      તમામ મિત્રો વડીલો શુભેચ્છકો શુભચિંતકો નો ખૂબ ખ...
# 84      આટલા બધા સમાજ ઘણા મોટા લેવલના સામાજિક આગેવાનો ...
#                               ...
# 5134    લખવા ખાતર તો આખો ફકરો લખી દઉં એની માટે પણ એ ફક...
# 5135    જય શ્રી કૃષ્ણ જ્ઞાન મેળવવા ની લાલસા જ માણસ ને ...
# 5136     અલ્યા હજાર ની પોલીસ ની ભરતી નો ફાંકો મારો છો ...
# 5137     શુભ સવાર જય શ્રી કૃષ્ણ ૭ વર્ષ પહેલાં દર્શન નો...
# 5138     આને પેટારો કહેવાય પણ આની ઉપર ગાદલાં અને ગોદળા...
# Name: tweet, Length: 3985, dtype: object

# %%
import pandas as pd
df1 = pd.DataFrame(output)
df1
df1.reset_index()
#df1.to_csv('new_valid_tweets.csv')
# Out:
#                                                   tweet
# 0      અમિતભાઈ કાશ્મીર ગયા જ છો તો દિવસ વધારે રોકાઈન...
# 1                          ગુજરાતહોમગાર્ડ નો પગાર વધારો
# 62     પોલીસ વાળા હપ્તા ઉઘરાવી ધંધો કરાવે છે એનું શુ...
# 83    તમામ મિત્રો વડીલો શુભેચ્છકો શુભચિંતકો નો ખૂબ ખ...
# 84    આટલા બધા સમાજ ઘણા મોટા લેવલના સામાજિક આગેવાનો ...
# ...                                                 ...
# 5134  લખવા ખાતર તો આખો ફકરો લખી દઉં એની માટે પણ એ ફક...
# 5135  જય શ્રી કૃષ્ણ જ્ઞાન મેળવવા ની લાલસા જ માણસ ને ...
# 5136   અલ્યા હજાર ની પોલીસ ની ભરતી નો ફાંકો મારો છો ...
# 5137   શુભ સવાર જય શ્રી કૃષ્ણ ૭ વર્ષ પહેલાં દર્શન નો...
# 5138   આને પેટારો કહેવાય પણ આની ઉપર ગાદલાં અને ગોદળા...
#
# [3985 rows x 1 columns]

# %%
df1.reset_index(inplace=True)
df1
# Out:
#       index                                              tweet
# 0         0   અમિતભાઈ કાશ્મીર ગયા જ છો તો દિવસ વધારે રોકાઈન...
# 1         1                       ગુજરાતહોમગાર્ડ નો પગાર વધારો
# 2        62   પોલીસ વાળા હપ્તા ઉઘરાવી ધંધો કરાવે છે એનું શુ...
# 3        83  તમામ મિત્રો વડીલો શુભેચ્છકો શુભચિંતકો નો ખૂબ ખ...
# 4        84  આટલા બધા સમાજ ઘણા મોટા લેવલના સામાજિક આગેવાનો ...
# ...     ...                                                ...
# 3980   5134  લખવા ખાતર તો આખો ફકરો લખી દઉં એની માટે પણ એ ફક...
# 3981   5135  જય શ્રી કૃષ્ણ જ્ઞાન મેળવવા ની લાલસા જ માણસ ને ...
# 3982   5136   અલ્યા હજાર ની પોલીસ ની ભરતી નો ફાંકો મારો છો ...
# 3983   5137   શુભ સવાર જય શ્રી કૃષ્ણ ૭ વર્ષ પહેલાં દર્શન નો...
# 3984   5138   આને પેટારો કહેવાય પણ આની ઉપર ગાદલાં અને ગોદળા...
#
# [3985 rows x 2 columns]

# %%
df1=df1.drop(['index'],axis=1)
df1
# Out:
#                                                   tweet
# 0      અમિતભાઈ કાશ્મીર ગયા જ છો તો દિવસ વધારે રોકાઈન...
# 1                          ગુજરાતહોમગાર્ડ નો પગાર વધારો
# 2      પોલીસ વાળા હપ્તા ઉઘરાવી ધંધો કરાવે છે એનું શુ...
# 3     તમામ મિત્રો વડીલો શુભેચ્છકો શુભચિંતકો નો ખૂબ ખ...
# 4     આટલા બધા સમાજ ઘણા મોટા લેવલના સામાજિક આગેવાનો ...
# ...                                                 ...
# 3980  લખવા ખાતર તો આખો ફકરો લખી દઉં એની માટે પણ એ ફક...
# 3981  જય શ્રી કૃષ્ણ જ્ઞાન મેળવવા ની લાલસા જ માણસ ને ...
# 3982   અલ્યા હજાર ની પોલીસ ની ભરતી નો ફાંકો મારો છો ...
# 3983   શુભ સવાર જય શ્રી કૃષ્ણ ૭ વર્ષ પહેલાં દર્શન નો...
# 3984   આને પેટારો કહેવાય પણ આની ઉપર ગાદલાં અને ગોદળા...
#
# [3985 rows x 1 columns]

# %%
df_clean.tweet.duplicated()
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 5134    False
# 5135    False
# 5136    False
# 5137    False
# 5138    False
# Name: tweet, Length: 5139, dtype: bool

# %%
df1.to_csv("gujarati_tweet_final.csv")
