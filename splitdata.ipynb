# %%
from google.colab import drive
drive.mount('/content/drive')\
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/drive/MyDrive/merge_annotate1-37.csv',lineterminator='\n')
df
# Out:
#       Unnamed: 0  ...  sentiment
# 0              0  ...          2
# 1              1  ...          1
# 2              2  ...          2
# 3              3  ...          2
# 4              4  ...          1
# ...          ...  ...        ...
# 3871          56  ...          2
# 3872          57  ...          2
# 3873          58  ...          2
# 3874          59  ...          2
# 3875          60  ...          2
#
# [3876 rows x 4 columns]

# %%
df_neg=df[df['sentiment']==0]
df_neg
# Out:
#       Unnamed: 0  ...  sentiment
# 7              7  ...          0
# 9              9  ...          0
# 21            21  ...          0
# 32            32  ...          0
# 34            34  ...          0
# ...          ...  ...        ...
# 3842          27  ...          0
# 3843          28  ...          0
# 3857          42  ...          0
# 3860          45  ...          0
# 3863          48  ...          0
#
# [515 rows x 4 columns]

# %%
# df_neg.reset_index(inplace=True)
# df_neg=df_neg.drop(['Unnamed: 0', 'Unnamed: 0.1','index'], axis = 1)
# df_neg

# %%
df_pos=df[df['sentiment']==2]

# %%
# df_pos.reset_index(inplace=True)
# df_pos=df_pos.drop(['Unnamed: 0', 'Unnamed: 0.1','index'], axis = 1)
# df_pos

# %%
df_nuetral=df[df['sentiment']==1]

# %%
# df_nuetral.reset_index(inplace=True)
# df_nuetral=df_nuetral.drop(['Unnamed: 0', 'Unnamed: 0.1','index'], axis = 1)
# df_nuetral

# %%
df_g=pd.read_csv('/content/drive/MyDrive/guru_merge.csv')
df_g
# Out:
#       Unnamed: 0  ...  sentiment
# 0              0  ...          0
# 1              1  ...          1
# 2              2  ...          2
# 3              3  ...          0
# 4              4  ...          0
# ...          ...  ...        ...
# 2866          94  ...          0
# 2867          95  ...          0
# 2868          96  ...          0
# 2869          97  ...          2
# 2870          98  ...          0
#
# [2871 rows x 5 columns]

# %%
df_g_neg=df_g[df_g['sentiment']==0]
df_g_neg
# Out:
#       Unnamed: 0  ...  sentiment
# 0              0  ...          0
# 3              3  ...          0
# 4              4  ...          0
# 5              5  ...          0
# 9              9  ...          0
# ...          ...  ...        ...
# 2860          88  ...          0
# 2866          94  ...          0
# 2867          95  ...          0
# 2868          96  ...          0
# 2870          98  ...          0
#
# [1211 rows x 5 columns]

# %%
# df_g_neg.reset_index(inplace=True)
# df_g_neg=df_g_neg.drop(['Unnamed: 0', 'Unnamed: 0.1','index'], axis = 1)
# df_g_neg

# %%
df_g_nuetal=df_g[df_g['sentiment']==1]

# %%
# df_g_nuetal.reset_index(inplace=True)
# df_g_nuetal=df_g_nuetal.drop(['Unnamed: 0', 'Unnamed: 0.1','index'], axis = 1)
# df_g_nuetal

# %%
df_g_pos=df_g[df_g['sentiment']==2]

# %%
df_a=pd.read_csv('/content/drive/MyDrive/ashay_merge.csv')
df_a
# Out:
#       Unnamed: 0  ...  sentiment
# 0              0  ...          2
# 1              1  ...          0
# 2              2  ...          2
# 3              3  ...          0
# 4              4  ...          2
# ...          ...  ...        ...
# 2129          94  ...          0
# 2130          95  ...          0
# 2131          96  ...          0
# 2132          97  ...          0
# 2133          98  ...          1
#
# [2134 rows x 5 columns]

# %%
df_a_nuetal=df_a[df_a['sentiment']==1]
df_a_nuetal
# Out:
#       Unnamed: 0  ...  sentiment
# 11            11  ...          1
# 12            12  ...          1
# 15            15  ...          1
# 31            31  ...          1
# 32            32  ...          1
# ...          ...  ...        ...
# 2123          88  ...          1
# 2125          90  ...          1
# 2126          91  ...          1
# 2128          93  ...          1
# 2133          98  ...          1
#
# [277 rows x 5 columns]

# %%
df_a_neg=df_a[df_a['sentiment']==0]
df_a_neg
# Out:
#       Unnamed: 0  ...  sentiment
# 1              1  ...          0
# 3              3  ...          0
# 5              5  ...          0
# 6              6  ...          0
# 7              7  ...          0
# ...          ...  ...        ...
# 2120          85  ...          0
# 2129          94  ...          0
# 2130          95  ...          0
# 2131          96  ...          0
# 2132          97  ...          0
#
# [1025 rows x 5 columns]

# %%
1143+409+277 #nuetral
# Out:
# 1829

# %%
515+1025+1211 #neg
# Out:
# 2751

# %%
final_neutral=pd.concat([df_nuetral,df_g_nuetal,df_a_nuetal])
final_neutral.reset_index(inplace=True)
final_neutral=final_neutral.drop(['Unnamed: 0', 'Unnamed: 0.1','Unnamed: 0.1.1','index'], axis = 1)
final_neutral
# Out:
#                                                   tweet  sentiment
# 0                          ગુજરાતહોમગાર્ડ નો પગાર વધારો          1
# 1     આટલા બધા સમાજ ઘણા મોટા લેવલના સામાજિક આગેવાનો ...          1
# 2      એ ચૂતમારીના ના બાપ ને લાફો મારી એમ સિખવડવું જ...          1
# 3      અજંપો એટલે એક એવી વ્યક્તિ નો વિરહ જે આપણી અંદ...          1
# 4     પોલીસ પરિવાર તથા પોલીસ મિત્રો તમામને જણાવવાનું...          1
# ...                                                 ...        ...
# 1824  દંડાત્મક નુકસાન સ્ટ્રાઈક બેક આલ્બમ કવર દ્વારા ...          1
# 1825   કદાચ ક્રિસમસ પહેલા બેઇજિંગ શેડ્યૂલ કરે છે તેઓ...          1
# 1826  કહો કે ચૂંટણી ચોરાઈ ગઈ હતી મહિનાઓ સુધી તેમનો ડ...          1
# 1827   જો તમે ઇચ્છો છો કે તે શીખવવામાં આવે તો વિરોધ ...          1
# 1828   ટ્રમ્પ બોલે તે પહેલા તેઓ સ્ક્રીન જોઈ રહ્યા હશ...          1
#
# [1829 rows x 2 columns]

# %%
X_nuetral=final_neutral.iloc[:,0:1]
X_nuetral
# Out:
#                                                   tweet
# 0                          ગુજરાતહોમગાર્ડ નો પગાર વધારો
# 1     આટલા બધા સમાજ ઘણા મોટા લેવલના સામાજિક આગેવાનો ...
# 2      એ ચૂતમારીના ના બાપ ને લાફો મારી એમ સિખવડવું જ...
# 3      અજંપો એટલે એક એવી વ્યક્તિ નો વિરહ જે આપણી અંદ...
# 4     પોલીસ પરિવાર તથા પોલીસ મિત્રો તમામને જણાવવાનું...
# ...                                                 ...
# 1824  દંડાત્મક નુકસાન સ્ટ્રાઈક બેક આલ્બમ કવર દ્વારા ...
# 1825   કદાચ ક્રિસમસ પહેલા બેઇજિંગ શેડ્યૂલ કરે છે તેઓ...
# 1826  કહો કે ચૂંટણી ચોરાઈ ગઈ હતી મહિનાઓ સુધી તેમનો ડ...
# 1827   જો તમે ઇચ્છો છો કે તે શીખવવામાં આવે તો વિરોધ ...
# 1828   ટ્રમ્પ બોલે તે પહેલા તેઓ સ્ક્રીન જોઈ રહ્યા હશ...
#
# [1829 rows x 1 columns]

# %%
Y_nuetral=final_neutral.iloc[:,1:]
Y_nuetral
# Out:
#       sentiment
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ...         ...
# 1824          1
# 1825          1
# 1826          1
# 1827          1
# 1828          1
#
# [1829 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

def split_xy(X,Y,str):
  X_train, X_test, y_train, y_test = train_test_split(X, Y,test_size=0.15)
  X_train.to_csv('X'+str+'train.csv')
  X_test.to_csv('X'+str+'test.csv')
  y_train.to_csv('Y'+str+'train.csv')
  y_test.to_csv('Y'+str+'test.csv')

# %%
split_xy(X_nuetral,Y_nuetral,'neutral')

# %%
final_pos=df_pos.iloc[0:1829,:]
final_pos.reset_index(inplace=True)
final_pos=final_pos.drop(['Unnamed: 0', 'Unnamed: 0.1','index'], axis = 1)
final_pos
# Out:
#                                                   tweet  sentiment
# 0      અમિતભાઈ કાશ્મીર ગયા જ છો તો દિવસ વધારે રોકાઈન...          2
# 1      પોલીસ વાળા હપ્તા ઉઘરાવી ધંધો કરાવે છે એનું શુ...          2
# 2     તમામ મિત્રો વડીલો શુભેચ્છકો શુભચિંતકો નો ખૂબ ખ...          2
# 3     અમદાવાદ જીલ્લા ભાજપ રાષ્ટ્રીય પ્રશિક્ષણ વર્ગ ૨...          2
# 4      તમામ મિત્રો વડીલો શુભેચ્છકો શુભચિંતકો નો ખૂબ ...          2
# ...                                                 ...        ...
# 1824  ઉત્તરાખંડમાં થયેલી કુદરતી હોનારત બાબતે પ્રદેશ ...          2
# 1825  જનતા ને સહન કરવાની ટેવ પડી ગઈ છે સરકાર નો વિરો...          2
# 1826   આવા ઉંધા કામ કર્યા કરતા એવી કંપની બનાવો જે આખ...          2
# 1827  માલધારીના બાળ નો ઠાકર રખેવાળ વર્ષના રબારી સમાજ...          2
# 1828   લગ્ન કરી નાખ જે ભાઈ આ નોકરી જાય છોકરી પણ જાય ...          2
#
# [1829 rows x 2 columns]

# %%
X_pos=final_pos.iloc[:,0:1]
Y_pos=final_pos.iloc[:,1:]

# %%
split_xy(X_pos,Y_pos,'pos')

# %%
final_neg=pd.concat([df_neg,df_g_neg,df_g_neg])
final_neg=final_neg.iloc[0:1829]
final_neg.reset_index(inplace=True)
final_neg=final_neg.drop(['Unnamed: 0', 'Unnamed: 0.1','Unnamed: 0.1.1','index'], axis = 1)
final_neg
# Out:
#                                                   tweet  sentiment
# 0           સાથ તું લાંબી મજલ નો સાર તું મારી ગઝલ નો ’           0
# 1     સુરતમાં ઝડપાયું દારૂ નું ગોડાઉન પણ પ્રશ્ન એ છે...          0
# 2     ગઈકાલ નો અફસોસ અને આવતી કાલ ની ચિંતા આ બંને એવ...          0
# 3     સામાન્ય લોકો ના ટેક્સ નો ખોટો ઉપયોગ અને પૈસા ન...          0
# 4      અગાઉના બધા તડકે મુકી મુકીને કડક કરતા ગ્યાતા સ...          0
# ...                                                 ...        ...
# 1824   દરમિયાન વિક નેશનલ્સના બોસ પીટર વોલ્શ અંતિમ સં...          0
# 1825   વિરોધ રૂપે હું માત્ર એક જ વસ્તુ કરી શકું છું ...          0
# 1826   અને છતાં કોઈ ખેલાડીઓએ વિરોધમાં પ્રેક્ટિસ છોડી...          0
# 1827   દરમિયાન વિક નેશનલ્સના બોસ પીટર વોલ્શ અંતિમ સં...          0
# 1828   દરમિયાન વિક નેશનલ્સના બોસ પીટર વોલ્શ અંતિમ સં...          0
#
# [1829 rows x 2 columns]

# %%
X_neg=final_neg.iloc[:,0:1]
Y_neg=final_neg.iloc[:,1:]

# %%
split_xy(X_neg,Y_neg,'neg')

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2)
print("\nX_train:\n")
print(X_train.head())
print(X_train.shape)

print("\nX_test:\n")
print(X_test.head())
print(X_test.shape)
