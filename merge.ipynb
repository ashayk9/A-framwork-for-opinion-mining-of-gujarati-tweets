# %%
list_pd = []
dir = "/content/drive/MyDrive/annotate/"
files = os.listdir(dir)
for file in files:
    list_pd.append((dir + file))

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd

# %%
list_pd
# Out:
# ['/content/drive/MyDrive/annotate/annotate1.csv',
#  '/content/drive/MyDrive/annotate/annotate4.csv',
#  '/content/drive/MyDrive/annotate/annotate3.csv',
#  '/content/drive/MyDrive/annotate/annotate5.csv',
#  '/content/drive/MyDrive/annotate/annotate2.csv',
#  '/content/drive/MyDrive/annotate/annotate6.csv',
#  '/content/drive/MyDrive/annotate/annotate21.csv',
#  '/content/drive/MyDrive/annotate/annotate26.csv',
#  '/content/drive/MyDrive/annotate/annotate24.csv',
#  '/content/drive/MyDrive/annotate/annotate22.csv',
#  '/content/drive/MyDrive/annotate/annotate16.csv',
#  '/content/drive/MyDrive/annotate/annotate36.csv',
#  '/content/drive/MyDrive/annotate/annotate13.csv',
#  '/content/drive/MyDrive/annotate/annotate7.csv',
#  '/content/drive/MyDrive/annotate/annotate11.csv',
#  '/content/drive/MyDrive/annotate/annotate33.csv',
#  '/content/drive/MyDrive/annotate/annotate9.csv',
#  '/content/drive/MyDrive/annotate/annotate37.csv',
#  '/content/drive/MyDrive/annotate/annotate32.csv',
#  '/content/drive/MyDrive/annotate/annotate30.csv',
#  '/content/drive/MyDrive/annotate/annotate25.csv',
#  '/content/drive/MyDrive/annotate/annotate18.csv',
#  '/content/drive/MyDrive/annotate/annotate12.csv',
#  '/content/drive/MyDrive/annotate/annotate14.csv',
#  '/content/drive/MyDrive/annotate/annotate15.csv',
#  '/content/drive/MyDrive/annotate/annotate17.csv',
#  '/content/drive/MyDrive/annotate/annotate20.csv',
#  '/content/drive/MyDrive/annotate/annotate27.csv',
#  '/content/drive/MyDrive/annotate/annotate28.csv',
#  '/content/drive/MyDrive/annotate/annotate29.csv',
#  '/content/drive/MyDrive/annotate/annotate34.csv',
#  '/content/drive/MyDrive/annotate/annotate8.csv',
#  '/content/drive/MyDrive/annotate/annotate31.csv',
#  '/content/drive/MyDrive/annotate/annotate10.csv',
#  '/content/drive/MyDrive/annotate/annotate23.csv',
#  '/content/drive/MyDrive/annotate/annotate19.csv',
#  '/content/drive/MyDrive/annotate/.ipynb_checkpoints']

# %%
list_pd.pop()
# Out:
# '/content/drive/MyDrive/annotate/.ipynb_checkpoints'

# %%
list_pd
# Out:
# ['/content/drive/MyDrive/annotate/annotate1.csv',
#  '/content/drive/MyDrive/annotate/annotate4.csv',
#  '/content/drive/MyDrive/annotate/annotate3.csv',
#  '/content/drive/MyDrive/annotate/annotate5.csv',
#  '/content/drive/MyDrive/annotate/annotate2.csv',
#  '/content/drive/MyDrive/annotate/annotate6.csv',
#  '/content/drive/MyDrive/annotate/annotate21.csv',
#  '/content/drive/MyDrive/annotate/annotate26.csv',
#  '/content/drive/MyDrive/annotate/annotate24.csv',
#  '/content/drive/MyDrive/annotate/annotate22.csv',
#  '/content/drive/MyDrive/annotate/annotate16.csv',
#  '/content/drive/MyDrive/annotate/annotate36.csv',
#  '/content/drive/MyDrive/annotate/annotate13.csv',
#  '/content/drive/MyDrive/annotate/annotate7.csv',
#  '/content/drive/MyDrive/annotate/annotate11.csv',
#  '/content/drive/MyDrive/annotate/annotate33.csv',
#  '/content/drive/MyDrive/annotate/annotate9.csv',
#  '/content/drive/MyDrive/annotate/annotate37.csv',
#  '/content/drive/MyDrive/annotate/annotate32.csv',
#  '/content/drive/MyDrive/annotate/annotate30.csv',
#  '/content/drive/MyDrive/annotate/annotate25.csv',
#  '/content/drive/MyDrive/annotate/annotate18.csv',
#  '/content/drive/MyDrive/annotate/annotate12.csv',
#  '/content/drive/MyDrive/annotate/annotate14.csv',
#  '/content/drive/MyDrive/annotate/annotate15.csv',
#  '/content/drive/MyDrive/annotate/annotate17.csv',
#  '/content/drive/MyDrive/annotate/annotate20.csv',
#  '/content/drive/MyDrive/annotate/annotate27.csv',
#  '/content/drive/MyDrive/annotate/annotate28.csv',
#  '/content/drive/MyDrive/annotate/annotate29.csv',
#  '/content/drive/MyDrive/annotate/annotate34.csv',
#  '/content/drive/MyDrive/annotate/annotate8.csv',
#  '/content/drive/MyDrive/annotate/annotate31.csv',
#  '/content/drive/MyDrive/annotate/annotate10.csv',
#  '/content/drive/MyDrive/annotate/annotate23.csv',
#  '/content/drive/MyDrive/annotate/annotate19.csv']

# %%
df = pd.concat(map(pd.read_csv, list_pd), ignore_index=True)
print(df)

# %%
import os
import glob
import pandas as pd
os.chdir("/content/drive/MyDrive/annotate/")

extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
#all_filenames
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
combined_csv
#export to csv
#combined_csv.to_csv( "combined_csv.csv", index=False, encoding='utf-8-sig')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-37-fc66772915f5> in <module>()
#       8 #all_filenames
#       9 #combine all files in the list
# ---> 10 combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#      11 combined_csv
#      12 #export to csv
#
# <ipython-input-37-fc66772915f5> in <listcomp>(.0)
#       8 #all_filenames
#       9 #combine all files in the list
# ---> 10 combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#      11 combined_csv
#      12 #export to csv
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     458
#     459     try:
# --> 460         data = parser.read(nrows)
#     461     finally:
#     462         parser.close()
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read(self, nrows)
#    1196     def read(self, nrows=None):
#    1197         nrows = _validate_integer("nrows", nrows)
# -> 1198         ret = self._engine.read(nrows)
#    1199
#    1200         # May alter columns / col_dict
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read(self, nrows)
#    2155     def read(self, nrows=None):
#    2156         try:
# -> 2157             data = self._reader.read(nrows)
#    2158         except StopIteration:
#    2159             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Buffer overflow caught - possible malformed input file.
